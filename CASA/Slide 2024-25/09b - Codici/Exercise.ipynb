# %% [markdown]
# # Classification algorithm for Hand Written Digits Dataset

# %%
import matplotlib.pyplot as plt

from sklearn import datasets

# Load the digits dataset
digits = datasets.load_digits()
  
_, axes = plt.subplots(nrows=1, ncols=10, figsize=(15, 3))
for ax, image, label in zip(axes, digits.images, digits.target):
    ax.set_axis_off()
    ax.imshow(image, cmap=plt.cm.gray_r, interpolation="nearest")
    ax.set_title("Training: %i" % label)
plt.show()
# Out:
# (8, 8)
# (8, 8)
# (8, 8)
# (8, 8)
# (8, 8)
# (8, 8)
# (8, 8)
# (8, 8)
# (8, 8)
# (8, 8)

# %% [markdown]
# Write a Neural Network model with this structure below to train and test the classification model. For the selection of the splitting of the samples as well as for any other parameter you are free to explore your solution.

# %% [markdown]
# <img src=".\images\nn_digits_exercise.png"/>
